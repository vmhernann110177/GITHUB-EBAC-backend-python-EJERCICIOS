# %% [markdown]
# <h2>Ejercicio Mod 5</h2>
# <ol type="I">
# <li> <FONT SIZE=4 COLOR="blue"> El objetivo de esta actividad </FONT> es que escribas un programa en un Jupyter Notebook <br>y que crees un analizador de sentimientos básico para un texto. Usando <FONT SIZE=3 COLOR="red"> python38 </FONT>
#     </li>
# <li> <FONT SIZE=4 COLOR="blue"> Archivos a desarrollar. </FONT>
#     <ol>
#         <li> Un Word con los siguientes puntos:
#             <ol>
#                 <li> Link a tu repositorio de Github con el Jupyter Notebook.
#                 </li>
#                 <li> Copia y pega tu código en el archivo de Word.
#                 </li>
#             </ol>
#         </li>
#     </ol>
# </li>
# <li> <FONT SIZE=4 COLOR="blue"> Ejercicio. </FONT>
#     <ol type="I">
#         <li> Copia y pega el código del recuadro <FONT SIZE=3 COLOR="green"> de este archivo: *.pdf </FONT> en tu Jupyter Notebook para realizar el ejercicio. <FONT SIZE=3 COLOR="red">Recuerda modificar este programa, de forma que sea más efectivo. Pon ejemplos para negativo, positivo y neutro.</FONT>
#         </li>
#         <li>
#             Añade este Jupyter Notebook a tu repositorio de Github con el nombre "Ejercicio – Strings / Cadenas".
#         </li>
#         <li>
#             En un archivo de Word pon el link a tu repositorio y copia y pega el código que creaste en tu Jupyter Notebook.
#         </li>
#         <li>
#             Al finalizar, responde la evaluación que encuentras en la plataforma.
#         </li>
#     </ol>
# </li>
# </ol>

# %%
## Analizador de sentimiento ------

### 1. EJEMPLO PARA SENTIMIENTO POSITIVO:

# Cadena a tratar, OJO modifiqué ligeramente la cadena:
# pln_string = "Este es un producto muy bueno, excelente, maravilloso, pero incompleto y básico"
nlp_string = """Este es un producto muy bueno, excelente, maravilloso, pero incompleto y básico"""

# 1. Quiero ver, en terminos de caracteres, algunas caracteristicas de la cadena que se lee:

print("\nQuiero ver, en terminos de caracteres, \nalgunas caracteristicas de la cadena que se lee:\n")
print("Todos los caracteres de la cadena son = \n\"", nlp_string[:],"\"")
print("\nEl número de caracteres que leo es =", len(nlp_string)) # esta leyendo 80 caracteres
print("El Caracter inicial es = |", nlp_string[0],"|")
print("El Caracter final es = |", nlp_string[-1],"|")

# CÓDIGO MODIFICADO:

my_string = nlp_string

neutral_words = ["producto", "básico"]
positive_words = ["bueno", "excelente", "maravilloso"]
negative_words = ["defectuoso", "malo", "horrible", "incompleto"]

positive_score = 0
negative_score = 0
neutral_score = 0
Result =""

for positive_word in positive_words:
    positive_score = positive_score + my_string.count(positive_word)

for negative_word in negative_words:
    negative_score = negative_score - my_string.count(negative_word)

for neutral_word in neutral_words:
    neutral_score = neutral_score + my_string.count(neutral_word)

print("\n\u001b[34mPRESENTACIÓN:" + "\033[0m")    
print( "Esto es un \033[1m" + "Analizador \u001b[31m MUY SENCILLO \u001b[30m de sentimiento \u001b[34m(Basado en un corto lexicón)." + "\033[0m")    
print("\nmy_string: \"{}\" ".format(my_string))
print("\nscore positivo, resultado = {}, resultado en valor absoluto = {}".format(positive_score, abs(positive_score)))
print("\nscore negativo, resultado = {}, resultado en valor absoluto = {}".format(negative_score, abs(negative_score)))
print("\nscore Neutro, resultado = {}, resultado en valor absoluto = {}".format(neutral_score, abs(neutral_score)))

if (abs(positive_score)>abs(negative_score) and abs(positive_score)>abs(neutral_score)):
    Result = "Positivo '+'"
    
if (abs(negative_score)>abs(positive_score) and abs(negative_score)>abs(neutral_score)):
    Result = "Negativo '-'"
    
if (abs(neutral_score)>abs(positive_score) and abs(neutral_score)>abs(negative_score)):
    Result = "Neutro '0'"
    
print("\nEn general se puede decir que el sentimiento de esta oracion es: {}".format(Result),"\n")
# Out:
# Quiero ver, en terminos de caracteres,
# algunas caracteristicas de la cadena que se lee:
#
# Todos los caracteres de la cadena son =
# " Este es un producto muy bueno, excelente, maravilloso, pero incompleto y básico "
#
# El número de caracteres que leo es = 79
# El Caracter inicial es = | E |
# El Caracter final es = | o |
#
# PRESENTACIÓN:
# Esto es un Analizador  MUY SENCILLO  de sentimiento (Basado en un corto lexicón).
#
# my_string: "Este es un producto muy bueno, excelente, maravilloso, pero incompleto y básico"
#
# score positivo, resultado = 3, resultado en valor absoluto = 3
#
# score negativo, resultado = -1, resultado en valor absoluto = 1
#
# score Neutro, resultado = 2, resultado en valor absoluto = 2
#
# En general se puede decir que el sentimiento de esta oracion es: Positivo '+'

# %%
## Analizador de sentimiento ---

### 2. EJEMPLO PARA SENTIMIENTO NEGATIVO:

# Cadena a tratar, OJO modifiqué ligeramente la cadena:
# pln_string = "Este es un producto muy bueno, excelente, maravilloso, pero incompleto y básico"
nlp_string = """Este es un gobierno muy malo, indolente, descortes y distraido con toda la ciudadania y las buenas personas"""

# 1. Quiero ver, en terminos de caracteres, algunas caracteristicas de la cadena que se lee:

print("\nQuiero ver, en terminos de caracteres, \nalgunas caracteristicas de la cadena que se lee:\n")
print("Todos los caracteres de la cadena son = \n\"", nlp_string[:],"\"")
print("\nEl número de caracteres que leo es =", len(nlp_string)) # esta leyendo 80 caracteres
print("El Caracter inicial es = |", nlp_string[0],"|")
print("El Caracter final es = |", nlp_string[-1],"|")

# CÓDIGO MODIFICADO:

my_string = nlp_string

neutral_words = ["gobierno", "ciudadania", "personas"]
positive_words = ["buenas", "excelente", "maravilloso", "cercano"]
negative_words = ["malo", "indolente", "descortes", "distraido"]

positive_score = 0
negative_score = 0
neutral_score = 0
Result =""

for positive_word in positive_words:
    positive_score = positive_score + my_string.count(positive_word)

for negative_word in negative_words:
    negative_score = negative_score - my_string.count(negative_word)

for neutral_word in neutral_words:
    neutral_score = neutral_score + my_string.count(neutral_word)

print("\n\u001b[34mPRESENTACIÓN:" + "\033[0m")    
print( "Esto es un \033[1m" + "Analizador \u001b[31m MUY SENCILLO \u001b[30m de sentimiento \u001b[34m(Basado en un corto lexicón)." + "\033[0m")    
print("\nmy_string: \"{}\" ".format(my_string))
print("\nscore positivo, resultado = {}, resultado en valor absoluto = {}".format(positive_score, abs(positive_score)))
print("\nscore negativo, resultado = {}, resultado en valor absoluto = {}".format(negative_score, abs(negative_score)))
print("\nscore Neutro, resultado = {}, resultado en valor absoluto = {}".format(neutral_score, abs(neutral_score)))

if (abs(positive_score)>abs(negative_score) and abs(positive_score)>abs(neutral_score)):
    Result = "Positivo '+'"
    
if (abs(negative_score)>abs(positive_score) and abs(negative_score)>abs(neutral_score)):
    Result = "Negativo '-'"
    
if (abs(neutral_score)>abs(positive_score) and abs(neutral_score)>abs(negative_score)):
    Result = "Neutro '0'"
    
print("\nEn general se puede decir que el sentimiento de esta oracion es: {}".format(Result),"\n")
# Out:
# Quiero ver, en terminos de caracteres,
# algunas caracteristicas de la cadena que se lee:
#
# Todos los caracteres de la cadena son =
# " Este es un gobierno muy malo, indolente, descortes y distraido con toda la ciudadania y las buenas personas "
#
# El número de caracteres que leo es = 107
# El Caracter inicial es = | E |
# El Caracter final es = | s |
#
# PRESENTACIÓN:
# Esto es un Analizador  MUY SENCILLO  de sentimiento (Basado en un corto lexicón).
#
# my_string: "Este es un gobierno muy malo, indolente, descortes y distraido con toda la ciudadania y las buenas personas"
#
# score positivo, resultado = 1, resultado en valor absoluto = 1
#
# score negativo, resultado = -4, resultado en valor absoluto = 4
#
# score Neutro, resultado = 3, resultado en valor absoluto = 3
#
# En general se puede decir que el sentimiento de esta oracion es: Negativo '-'

# %%
## Analizador de sentimiento ---

### 3. EJEMPLO PARA SENTIMIENTO NEUTRO:

# Cadena a tratar, OJO modifiqué ligeramente la cadena:
# pln_string = "Este es un producto muy bueno, excelente, maravilloso, pero incompleto y básico"
nlp_string = """Actualmente en este año 2023, vivimos épocas de muchos cambios, 
algunos positivos y otros negativos, quizá unos más que otros, 
pero la humanidad crece con lo que puede y así seguimos con nuestra vida. """

# 1. Quiero ver, en terminos de caracteres, algunas caracteristicas de la cadena que se lee:

print("\nQuiero ver, en terminos de caracteres, \nalgunas caracteristicas de la cadena que se lee:\n")
print("Todos los caracteres de la cadena son = \n\"", nlp_string[:],"\"")
print("\nEl número de caracteres que leo es =", len(nlp_string)) # esta leyendo 80 caracteres
print("El Caracter inicial es = |", nlp_string[0],"|")
print("El Caracter final es = |", nlp_string[-1],"|")

# CÓDIGO MODIFICADO:

my_string = nlp_string

neutral_words = ["Actualmente", "épocas", "cambios", "algunos", "unos", "otros", "humanidad"]
positive_words = ["positivos", "crece","excelente", "maravilloso", "cercano", "vida"]
negative_words = ["negativos", "indolente", "descortes", "distraido", "muerte"]

positive_score = 0
negative_score = 0
neutral_score = 0
Result =""

for positive_word in positive_words:
    positive_score = positive_score + my_string.count(positive_word)

for negative_word in negative_words:
    negative_score = negative_score - my_string.count(negative_word)

for neutral_word in neutral_words:
    neutral_score = neutral_score + my_string.count(neutral_word)

print("\n\u001b[34mPRESENTACIÓN:" + "\033[0m")    
print( "Esto es un \033[1m" + "Analizador \u001b[31m MUY SENCILLO \u001b[30m de sentimiento \u001b[34m(Basado en un corto lexicón)." + "\033[0m")    
print("\nmy_string: \"{}\" ".format(my_string))
print("\nscore positivo, resultado = {}, resultado en valor absoluto = {}".format(positive_score, abs(positive_score)))
print("\nscore negativo, resultado = {}, resultado en valor absoluto = {}".format(negative_score, abs(negative_score)))
print("\nscore Neutro, resultado = {}, resultado en valor absoluto = {}".format(neutral_score, abs(neutral_score)))

if (abs(positive_score)>abs(negative_score) and abs(positive_score)>abs(neutral_score)):
    Result = "Positivo '+'"
    
if (abs(negative_score)>abs(positive_score) and abs(negative_score)>abs(neutral_score)):
    Result = "Negativo '-'"
    
if (abs(neutral_score)>abs(positive_score) and abs(neutral_score)>abs(negative_score)):
    Result = "Neutro '0'"
    
print("\nEn general se puede decir que el sentimiento de esta oracion es: {}".format(Result),"\n")
# Out:
# Quiero ver, en terminos de caracteres,
# algunas caracteristicas de la cadena que se lee:
#
# Todos los caracteres de la cadena son =
# " Actualmente en este año 2023, vivimos épocas de muchos cambios,
# algunos positivos y otros negativos, quizá unos más que otros,
# pero la humanidad crece con lo que puede y así seguimos con nuestra vida.  "
#
# El número de caracteres que leo es = 203
# El Caracter inicial es = | A |
# El Caracter final es = |   |
#
# PRESENTACIÓN:
# Esto es un Analizador  MUY SENCILLO  de sentimiento (Basado en un corto lexicón).
#
# my_string: "Actualmente en este año 2023, vivimos épocas de muchos cambios,
# algunos positivos y otros negativos, quizá unos más que otros,
# pero la humanidad crece con lo que puede y así seguimos con nuestra vida. "
#
# score positivo, resultado = 3, resultado en valor absoluto = 3
#
# score negativo, resultado = -1, resultado en valor absoluto = 1
#
# score Neutro, resultado = 9, resultado en valor absoluto = 9
#
# ...

# %%
print("Programa terminado")
# Out:
# Programa terminado
