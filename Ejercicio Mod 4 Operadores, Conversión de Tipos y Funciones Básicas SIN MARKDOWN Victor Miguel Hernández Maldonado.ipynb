# %%
print("\n_________________-------------_______________________")  
print("_________________-------------_______________________\n") 
#  1.1  Definición de diccionario de bases.
# Bases
print("\n - Diccionario de Bases:")
my_bases_dictionary = {"H":"Hexadecimal", "D":"Decimal", "O":"Octal", "B":"Binaria"}
print("La Bases que puede usar esta calculadora son:",my_bases_dictionary)
print("La variable: 'my_bases_dictionary' es de tipo: ", type(my_bases_dictionary))

#  1.2  Definición de diccionario de operadores.
# Operadores
print("\n - Diccionario de Operadores:")
my_operators_dictionary = {"+":"Suma", "-":"Resta", "*":"Multiplicación", "/":"División" , "**":"Potencia"}
print("Los Operadores que se pueden usar son:", my_operators_dictionary)
print("La variable: 'my_operators_dictionary' es de tipo: ", type(my_operators_dictionary))

## 

print("\n_________________-------------_______________________")
print("_________________-------------_______________________\n")
#  2.1  Definición de bases que el usuario guste para sus operaciones.
b1,b2,b3,b4,b5  = input("Separadas por un espacio. \nSOLO escribe la LETRA inicial -EN MAYUSCULA- \
                        \nDe 5 (CINCO) bases para TUS operaciones: por ejemplo: \
                        \nB O H D B").split(" ")
print("Elegiste que la base de tu 1er operación sea: ", my_bases_dictionary[b1])
print("Elegiste que la base de tu 2da operación sea: ", my_bases_dictionary[b2])
print("Elegiste que la base de tu 3ra operación sea: ", my_bases_dictionary[b3])
print("Elegiste que la base de tu 4ta operación sea: ", my_bases_dictionary[b4])
print("Elegiste que la base de tu 5ta operación sea: ", my_bases_dictionary[b5])

##

print("\n_________________-------------_______________________")
print("_________________-------------_______________________\n")
#  2.2 Construccion del diccionario con las 5 bases definidas por el usuario.
# Solo corre esta linea.
usr_bases_dictionary = {
'1':my_bases_dictionary[b1], 
'2':my_bases_dictionary[b2], 
'3':my_bases_dictionary[b3], 
'4':my_bases_dictionary[b4], 
'5':my_bases_dictionary[b5]}

print("La base de tu 1er operación es: ", my_bases_dictionary[b1])
print("La base de tu 2da operación es: ", my_bases_dictionary[b2])
print("La base de tu 3ra operación es: ", my_bases_dictionary[b3])
print("La base de tu 4ta operación es: ", my_bases_dictionary[b4])
print("La base de tu 5ta operación es: ", my_bases_dictionary[b5])
print("_____________________________________________\n")
print("usr_bases_dictionary:", usr_bases_dictionary)
print("usr_bases_dictionary type:",type(usr_bases_dictionary))
print("_____________________________________________\n")

##

print("\n_________________-------------_______________________")
print("_________________-------------_______________________\n")
# 3.1 Pide las 5 operaciones que se llevarán a cabo. 
op1,op2,op3,op4,op5 = input("Separados por un espacio, \nEscribe UNICAMENTE los 5 símbolos de la operaciones que deseas hacer,por ejemplo: \
                             \n+ - * / **").split(" ")

print("Elegiste que tu 1er operación sea: ", my_operators_dictionary[op1])
print("Elegiste que tu 2da operación sea: ", my_operators_dictionary[op2])
print("Elegiste que tu 3ra operación sea: ", my_operators_dictionary[op3])
print("Elegiste que tu 4ta operación sea: ", my_operators_dictionary[op4])
print("Elegiste que tu 5ta operación sea: ", my_operators_dictionary[op5])

##

print("\n_________________-------------_______________________")
print("_________________-------------_______________________\n")
# 3.2 Construcción del diccionario de las 5 operaciones que se llevarán a cabo. 
# SOLO CORRE ESTA LINEA.
usr_OPE_dictionary = {
'1':my_operators_dictionary[op1], 
'2':my_operators_dictionary[op2], 
'3':my_operators_dictionary[op3], 
'4':my_operators_dictionary[op4], 
'5':my_operators_dictionary[op5]}

print("\n***")
print("usr_operations_dictionary:", usr_OPE_dictionary)
print("usr_operations_dictionary type:",type(usr_OPE_dictionary))
print("***\n")

usr_OPE_Lista = [op1,op2,op3,op4,op5]
print("usr_OPE_Lista:",usr_OPE_Lista,"usr_OPE_Lista, type:", type(usr_OPE_Lista))

## 

print("\n_________________-------------_______________________")
print("_________________-------------_______________________\n")
# 4. Mensaje de aviso de consideraciones preliminares.
print("MENSAJE CONSIDERACIONES PRELIMINARES:\n")
print("SI ELEGISTE BASE HEXADECIMAL.\n- TIENES TRES FORMAS DE ESTABLECER TUS VALORES Y UNA CONSIDERACIÓN: \
           \n1. PON VALORES EN BASE DECIMAL, CON DIGITOS DEL 0 AL 9, NO SE PERMITEN NUMEROS NEGATIVOS. \
           \n2. PON VALORES EN SU FORMA HEXADECIMAL: NUMEROS ENTEROS CON DIGITOS DEL 0 AL 9 Y LAS LETRAS: A B C D E F: p.eJ. 0xA 0xB\
           \n3. PUEDES PROPONER TUS VALORES DE FORMA HIBRIDA: p.ej. 10 , 0x99  \
           \nCONSIDERACIÓN *IMPORTANTE*: NO USES VALORES DE TIPO 'FLOAT'" )

print("\nSI ELEGISTE BASE DECIMAL, \n- TIENES VARIAS FORMAS DE ESTABLECER TUS VALORES: \
            \n1. PUEDES USAR NÚMEROS ENTEROS CON DIGITOS DEL 0 AL 9 \
            \n2. SI PUEDES USAR NUMERODS NEGATIVOS \
            \n3. PUEDES USAR CUALQUIER VALORES DE TIPO FLOAT. \
            \n4. PUEDES PROPONER TUS VALORES DE FORMA HIBRIDA, es decir: ENTERO, NEGATIVO y FLOAT")

print("\nSI ELEGISTE BASE OCTAL. \n- TIENES TRES FORMAS DE ESTABLECER TUS VALORES Y UNA CONSIDERACIÓN:\
           \n1. PUEDES PONER VALORES, EN BASE DECIMAL, SOLO DIGITOS DEL 0 AL 7 \
           \n2. PUEDES SUGERIR LOS VALORES EN SU FORMA OCTAL: NUMEROS ENTEROS CON DIGITOS DEL 0 AL 7, p.ej. 0o1, 0o7, -0o7, -0o77\
           \n3. PUEDES PROPONER TUS VALORES DE FORMA HIBRIDA: p.ej. 70, 0o56  \
           \nCONSIDERACIÓN *IMPORTANTE*: NO USES VALORES DE TIPO 'FLOAT'" )

print("\nSI ELEGISTE BASE BASE BINARIA. \n-  PUEDES USAR VALORES EN BASE 10 Ó VALORES EN BASE BINARIA, \
           \nEn este último caso SOLO PUEDES USAR DIGITOS (1 ó 0) y con el prefijo '0b', p.ej. 0b1110")

##

# 5.1 Recuerda al usuario bases y operaciones que eligió antes de pedirle la lista de números.
print("\n_________________-------------_______________________")
print("_________________-------------_______________________\n")
print("Te recuerdo que las bases que elegiste son:\n",usr_bases_dictionary)
print("usr_bases_dictionary, Type:", type(usr_bases_dictionary))

print("\n_________________-------------_______________________")
print("_________________-------------_______________________\n")
print("Te recuerdo que las operaciones que elegiste son:\n", usr_OPE_dictionary)
print("usr_OPE_dictionary, Type:", type(usr_OPE_dictionary))

##

print("\n_________________-------------_______________________")
print("_________________-------------_______________________\n")
# 5.2 Pide los 5 primeros operandos
v11,v12,v13,v14,v15 = input("Separados por un espacio, escribe los primeros 5 VALORES u OPERANDOS por ejemplo: \
                             \n0b111 63 512 99.569 5").split(" ")
print("1er valor operando: ", v11, type(v11))
print("2do valor operando: ", v12, type(v12))
print("3er valor operando: ", v13, type(v13))
print("4to valor operando: ", v14, type(v14))
print("5to valor operando: ", v15, type(v15))

##

print("\n_________________-------------_______________________")
print("_________________-------------_______________________\n")
# 5.3: Crea su LISTA.
lista_Operando1 = [v11,v12,v13,v14,v15]
print("Los valores de los primeros operandos, tal como fueron escritos son: ", lista_Operando1)
lista_Operando1_Dec = [eval(lista_Operando1[0]),
                       eval(lista_Operando1[1]),
                       eval(lista_Operando1[2]),
                       eval(lista_Operando1[3]),
                       eval(lista_Operando1[4])]
print("Los valores de los primeros operandos, en base decimal son: ", lista_Operando1_Dec)
print("lista_Operando1_Dec, Type:",type(lista_Operando1_Dec))

##

# 6.1: Recuerda al usuario bases y operaciones que eligió antes de pedirle la lista de números

print("\n_________________-------------_______________________")
print("_________________-------------_______________________\n")
print("Te recuerdo que las bases que elegiste son:\n",usr_bases_dictionary)
print("usr_bases_dictionary, Type:", type(usr_bases_dictionary))

print("\n_________________-------------_______________________")
print("_________________-------------_______________________\n")
print("Te recuerdo que las operaciones que elegiste son:\n", usr_OPE_dictionary)
print("usr_OPE_dictionary, Type:", type(usr_OPE_dictionary))

##

print("\n_________________-------------_______________________")
print("_________________-------------_______________________\n")
# 6.2: Pide los 5 segundos operandos 
v21,v22,v23,v24,v25 = input("Separados por un espacio, escribe los segundos 5 valores OPERANDOS por ejemplo: \
                             \n3 0o106 0x2 8.452 0b10").split(" ")
print("1er operando: ", v21, type(v21))
print("2do operando: ", v22, type(v22))
print("3er operando: ", v23, type(v23))
print("4to operando: ", v24, type(v24))
print("5to operando: ", v25, type(v25))

##

print("\n_________________-------------_______________________")
print("_________________-------------_______________________\n")
# 6.3: Crea su LISTA.
Lista_Operando2 = [v21,v22,v23,v24,v25]
print("Los valores de los segundos operandos, tal como fueron escritos son: ", Lista_Operando2)
lista_Operando2_Dec = [eval(Lista_Operando2[0]),
                       eval(Lista_Operando2[1]),
                       eval(Lista_Operando2[2]),
                       eval(Lista_Operando2[3]),
                       eval(Lista_Operando2[4])]
print("Los valores de los segundos operandos, en base decimal son: ", lista_Operando2_Dec)
print("lista_Operando2_Dec, Type:",type(lista_Operando2_Dec))

##

print("\n_________________-------------_______________________")
print("_________________-------------_______________________\n")
# 7. Resumen de información proporcionada por el usuario.
print("\nRESUMEN:\
      \n\nLas BASES que elegiste son: \n\n", usr_bases_dictionary)
print("\nLas OPERACIONES que elegiste son: \n", usr_OPE_dictionary)
print("\nLista_Operando1 como fue escrita:", lista_Operando1,", Type:", type(lista_Operando1),
      "\nLista_Operando2 como fue escrita:", Lista_Operando2,", Type:", type(Lista_Operando2))
print("lista_Operando1 en decimal:",lista_Operando1_Dec,", Type:",type(lista_Operando1_Dec))
print("lista_Operando2 en decimal:",lista_Operando2_Dec,", Type:",type(lista_Operando2_Dec))
##

# 8. Ejecuta operaciones.
print("\n_________________-------------_______________________")
print("_________________-------------_______________________\n\n")
print("         COMIENZAN CÁLCULOS DE LA CALCULADORA          \n")
print("_________________-------------_______________________")
print("_________________-------------_______________________\n\n")

# Declaro variables globales tipo entero o float que usaré como referencia.
vIntRef = 1
#print ("vIntRef es de tipo:",type(vIntRef))
vFloatRef = 0.1
#print ("vFloatRef es de tipo:",type(vFloatRef))

# Crea un contador : i (variable global) para saber que base y que operación se estará haciendo. 
i=-1
for usr_base in usr_bases_dictionary:
    
    # Lee la base actual que estas trabajando apoyada en 'usr_base'
    curren_base = usr_bases_dictionary[usr_base]
    
    # Aquí El contador "i" ayuda a saber cual es el subindice de la BASE actualmente a realizar.
    i=i+1
    # Imprime la base que etas trabajando actualmente

    print("________________________________________________________________\n")
    print(i+1,"- Base elegida:",curren_base)
    print("¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯")
################## INICIA BASE DECIMAL ##################

    if curren_base == 'Decimal':

        # Aquí El contador "i+1" ayuda a saber cual es el subindice de la OPERACIÓN actualmente a realizar.
        
        print("LA OPERACION \033[1m",(i+1),"\033[0m es:\033[1m",usr_OPE_dictionary[usr_base],
              "\033[0m; Y ESTÁ EN BASE \033[1mDECIMAL\033[0m.")
        
        # Haz un cambio implicito del valor de 'lista_Operando1[i]'' a tipo Decimal con 'eval()''.
        v1 = eval(lista_Operando1[i])
       # Haz un cambio implicito del valor de 'lista_Operando2[i]'' a tipo Decimal con 'eval()''.
        v2 = eval(Lista_Operando2[i])
        print("\nSus operandos tienen el valor en base decimal de:")
        print ("v1=",v1,"\nv2=",v2,"\n")
        
        # PARA v1:
        #Declaro un swich tipo 'bool' para permitir o negar la operación si V1 no es del tipo correcto de acuerdo a la base
        blnv1AceptaOpDecimal = False 
        if type(v1)==type(vIntRef) or type(v1)==type(vFloatRef):
            print ("La variable v1 es de tipo:", type(v1), ", por lo que se acepta")
            blnv1AceptaOpDecimal = True
        
        # Establezco un valor limite maximo y minimo para V1 y uso el swich anterior 
        # para reafirmar o cancelar la ejecución de la operación    
        if v1<=2147483647 and v1>=-2147483647:
            print ("v1 también entra en los rangos permitidos, y también se acepta")
            blnv1AceptaOpDecimal = True
        else:
            print ("La variable v1 NO entra en los rangos permitidos, por lo que SE RECHAZA")
            blnv1AceptaOpDecimal = False
            
        # PARA v2:
        #Declaro un swich tipo 'bool' para permitir o negar la operación si V1 no es del tipo correcto de acuerdo a la base
        blnv2AceptaOpDecimal = False 
        if type(v2)==type(vIntRef) or type(v2)==type(vFloatRef):
            print ("La variable v2 es de tipo:", type(v1), ", por lo que se acepta")
            blnv2AceptaOpDecimal = True
            
        # Establezco un valor limite maximo y minimo para V1 y uso el swich anterior 
        # para reafirmar o cancelar la ejecución de la operación    
        if v1<=2147483647 and v1>=-2147483647:
            print ("v2 también entra en los rangos permitidos, y también se acepta")
            blnv2AceptaOpDecimal = True
        else:
            print ("\nLa variable v2 NO entra en los rangos permitidos, por lo que SE RECHAZA")
            blnv2AceptaOpDecimal = False
#             
                
        ## Si lo swiches anteriores son verdaderos se ejecuta la operación
        ### si no, habra aparecido un mensaje donde se ubica el fallo.
        if blnv1AceptaOpDecimal== True and blnv2AceptaOpDecimal== True:
            print("\nPor lo tanto, los valores que has introducido \033[1mSON ACEPTADOS\033[0m para realizar dicha operación")
            #*# Inicia zona de ejecucion de operación:
            
            ## Imprimi para verlo, 
            ## esta linea se puede comentar para limpiar el código
            #print(usr_OPE_Lista[i]) 
            
            my_operation_symbol = usr_OPE_Lista[i]
                 
            if my_operation_symbol == '+':
                print("\n\033[1mA PARTIR DE ESTE MOMENTO LA OPERACIÓN SE HACE EXCLUSIVAMENTE DE LA BASE DECIMAL:\033[0m")
                v0 = v1+v2
                print("\nEl resultado de la operación:\033[1m", my_operators_dictionary[my_operation_symbol], 
                      "\033[0m",v1,usr_OPE_Lista[i],v2,
                ", \033[1men base", usr_bases_dictionary[usr_base], 
                      "es:",  '%.4f' % v0,"\033[0m", "Tipo:" ,type(v0))
                #RESP:# El resultado de la operación: *Suma*  5 + 10 *en base Decimal es: 15*  Tipo: <class 'int'>
            
            if my_operation_symbol == '-':
                print("\n\033[1mA PARTIR DE ESTE MOMENTO LA OPERACIÓN SE HACE EXCLUSIVAMENTE DE LA BASE DECIMAL:\033[0m")
                v0 = v1-v2
                print("\nEl resultado de la operación:\033[1m", my_operators_dictionary[my_operation_symbol], 
                      "\033[0m",v1,usr_OPE_Lista[i],v2,
                "\033[1men base", usr_bases_dictionary[usr_base], 
                      "es:",  '%.4f' % v0,"\033[0m", "Tipo:" ,type(v0))
                #RESP:# El resultado de la operación: *Resta*  2 - 2 *en base Decimal es: 0*  Tipo: <class 'int'>
            
            if my_operation_symbol == '*':
                print("\n\033[1mA PARTIR DE ESTE MOMENTO LA OPERACIÓN SE HACE EXCLUSIVAMENTE DE LA BASE DECIMAL:\033[0m")
                v0 = v1*v2
                print("\nEl resultado de la operación:\033[1m", my_operators_dictionary[my_operation_symbol], 
                      "\033[0m",v1,usr_OPE_Lista[i],v2,
                "\033[1men base", usr_bases_dictionary[usr_base], 
                      "es:",  '%.4f' % v0,"\033[0m", "Tipo:" ,type(v0))
                #RESP:# El resultado de la operación: Multiplicación  5 * 10 en base Decimal es: 50  Tipo: <class 'int'>
                
            if my_operation_symbol == '/':
                print("\n\033[1mA PARTIR DE ESTE MOMENTO LA OPERACIÓN SE HACE EXCLUSIVAMENTE DE LA BASE DECIMAL:\033[0m")
                v0 = v1/v2
                print("\n\033[1mSE APLICÁ FORMATO VISTO EN CLASE ('%.4f' % ) AL RESULTADO DE ESTA OPERACION:  \033[0m")
                print("\nEl resultado de la operación:\033[1m", my_operators_dictionary[my_operation_symbol], 
                      "\033[0m",v1,usr_OPE_Lista[i],v2,
                "\033[1men base", usr_bases_dictionary[usr_base], 
                      "es:",  '%.4f' % v0,"\033[0m", "Tipo:" ,type(v0))
                #RESP:# El resultado de la operación: División  5 / 10 en base Decimal es: 0.5  Tipo: <class 'float'>

            if my_operation_symbol == '**':
                print("\n\033[1mA PARTIR DE ESTE MOMENTO LA OPERACIÓN SE HACE EXCLUSIVAMENTE DE LA BASE DECIMAL:\033[0m")
                v0 = v1**v2
                print("\nEl resultado de la operación:\033[1m", my_operators_dictionary[my_operation_symbol], 
                      "\033[0m",v1,usr_OPE_Lista[i],v2,
                "\033[1men base", usr_bases_dictionary[usr_base], 
                      "es:",  '%.4f' % v0,"\033[0m", "Tipo:" ,type(v0))
                #RESP:# El resultado de la operación: Potencia  5 ** 10 en base Decimal es: 9765625  Tipo: <class 'int'>
                
################## FIN BASE DECIMAL ##################   

#

################## INICIA BASE OCTAL #################  

    if curren_base == 'Octal':

        # Aquí El contador "i+1" ayuda a saber cual es el subindice de la OPERACIÓN actualmente a realizar.
        
        print("LA OPERACION \033[1m",(i+1),"\033[0m es:\033[1m",usr_OPE_dictionary[usr_base],
              "\033[0m; Y ESTÁ EN BASE \033[1mOCTAL\033[0m.")
        
        # Haz un cambio implicito del valor de 'lista_Operando1[i]'' a tipo Decimal con 'eval()''.
        v1 = eval(lista_Operando1[i])
       # Haz un cambio implicito del valor de 'lista_Operando2[i]'' a tipo Decimal con 'eval()''.
        v2 = eval(Lista_Operando2[i])
        print("\nSus operandos tienen el valor en base decimal de:")
        print ("v1=",v1,"\nv2=",v2)
        
        print("\nSus operandos tienen el valor en base Octal de:")
        print ("v1=",oct(v1),"\nv2=",oct(v2),"\n")
        
        # PARA v1:
        #Declaro un swich tipo 'bool' para permitir o negar la operación si V1 no es del tipo correcto de acuerdo a la base
        blnv1AceptaOpOctal = False 
        if type(v1)==type(vIntRef) or type(v1)==type(vFloatRef):
            print ("La variable v1 es de tipo:", type(v1), ", por lo que se acepta")
            blnv1AceptaOpOctal = True
        
        # Establezco un valor limite maximo y minimo para V1 y uso el swich anterior 
        # para reafirmar o cancelar la ejecución de la operación    
        if v1<=2147483647 and v1>=-2147483647:
            print ("v1 también entra en los rangos permitidos, y también se acepta")
            blnv1AceptaOpOctal = True
        else:
            print ("La variable v1 NO entra en los rangos permitidos, por lo que SE RECHAZA")
            blnv1AceptaOpOctal = False
            
        # PARA v2:
        #Declaro un swich tipo 'bool' para permitir o negar la operación si V1 no es del tipo correcto de acuerdo a la base
        blnv2AceptaOpOctal = False 
        if type(v2)==type(vIntRef) or type(v2)==type(vFloatRef):
            print ("La variable v2 es de tipo:", type(v1), ", por lo que se acepta")
            blnv2AceptaOpOctal = True
            
        # Establezco un valor limite maximo y minimo para V1 y uso el swich anterior 
        # para reafirmar o cancelar la ejecución de la operación    
        if v1<=2147483647 and v1>=-2147483647:
            print ("v2 también entra en los rangos permitidos, y también se acepta")
            blnv2AceptaOpOctal = True
        else:
            print ("\nLa variable v2 NO entra en los rangos permitidos, por lo que SE RECHAZA")
            blnv2AceptaOpOctal = False
                
        ## Si lo swiches anteriores son verdaderos se ejecuta la operación
        ### si no, habra aparecido un mensaje donde se ubica el fallo.
        if blnv1AceptaOpOctal== True and blnv2AceptaOpOctal== True:
            print("\nPor lo tanto, los valores que has introducido \033[1mSON ACEPTADOS\033[0m para realizar dicha operación")
            #*# Inicia zona de ejecucion de operación:
            
            ## Imprimi para verlo, 
            ## esta linea se puede comentar para limpiar el código
            #print(usr_OPE_Lista[i]) 
            
            my_operation_symbol = usr_OPE_Lista[i]
                 
            if my_operation_symbol == '+':
                
                v1 = str(v1)
                v2 = str(v2)
                
                print("\n\033[1mA PARTIR DE ESTE MOMENTO LA OPERACIÓN SE HACE EXCLUSIVAMENTE DE LA BASE OCTAL:\033[0m")
                
                print("\nEl resultado de la operación:\033[1m", my_operators_dictionary[my_operation_symbol],
                      oct(int(v1)), usr_OPE_Lista[i], oct(int(v2)))
                
                # Hago conversión explicita, es decir: hex(int(int/int))
                sumaoctal = oct(int(int(v1) + int(v2)))
                print("En base \033[1m", usr_bases_dictionary[usr_base],"es:", sumaoctal,"\033[0m")
                my_octal_number = int(eval(sumaoctal)) 
                print("\033[1mEl resultado en decimal es: ", my_octal_number,"\033[0m") 
                  
            if my_operation_symbol == '-':
                
                v1 = str(v1)
                v2 = str(v2)
                
                print("\n\033[1mA PARTIR DE ESTE MOMENTO LA OPERACIÓN SE HACE EXCLUSIVAMENTE DE LA BASE OCTAL:\033[0m")
                
                print("\nEl resultado de la operación:\033[1m", my_operators_dictionary[my_operation_symbol],
                      oct(int(v1)), usr_OPE_Lista[i], oct(int(v2)))
                
                # Hago conversión explicita, es decir: hex(int(int/int))
                restaOctal = oct(int(int(v1) - int(v2)))
                print("En base \033[1m", usr_bases_dictionary[usr_base],"es:", restaOctal,"\033[0m")
                my_octal_number = int(eval(restaOctal)) 
                print("\033[1mEl resultado en decimal es: ", my_octal_number,"\033[0m") 
            
            if my_operation_symbol == '*':
                
                v1 = str(v1)
                v2 = str(v2)
                
                print("\n\033[1mA PARTIR DE ESTE MOMENTO LA OPERACIÓN SE HACE EXCLUSIVAMENTE DE LA BASE OCTAL:\033[0m")
                
                print("\nEl resultado de la operación:\033[1m", my_operators_dictionary[my_operation_symbol],
                      oct(int(v1)), usr_OPE_Lista[i], oct(int(v2)))
                
                # Hago conversión explicita, es decir: hex(int(int/int))
                multiOctal = oct(int(int(v1) * int(v2)))
                print("En base \033[1m", usr_bases_dictionary[usr_base],"es:", multiOctal,"\033[0m")
                my_octal_number = int(eval(multiOctal)) 
                print("\033[1mEl resultado en decimal es: ", my_octal_number,"\033[0m") 
                
            if my_operation_symbol == '/':

                v1 = str(v1)
                v2 = str(v2)
                
                print("\n\033[1mA PARTIR DE ESTE MOMENTO LA OPERACIÓN SE HACE EXCLUSIVAMENTE DE LA BASE OCTAL:\033[0m")
                
                print("\nEl resultado de la operación:\033[1m", my_operators_dictionary[my_operation_symbol],
                      oct(int(v1)), usr_OPE_Lista[i], oct(int(v2)))
                
                # Hago conversión explicita, es decir: hex(int(int/int))
                divOctal = oct(int(int(v1) / int(v2)))
                print("En base \033[1m", usr_bases_dictionary[usr_base],"es:", divOctal,"\033[0m")
                my_octal_number = int(eval(divOctal)) 
                print("\033[1mEl resultado en decimal es: ", my_octal_number,"\033[0m") 
                
            if my_operation_symbol == '**':

                v1 = str(v1)
                v2 = str(v2)
                
                print("\n\033[1mA PARTIR DE ESTE MOMENTO LA OPERACIÓN SE HACE EXCLUSIVAMENTE DE LA BASE OCTAL:\033[0m")
                
                print("\nEl resultado de la operación:\033[1m", my_operators_dictionary[my_operation_symbol],
                      oct(int(v1)), usr_OPE_Lista[i], oct(int(v2)))
                
                # Hago conversión explicita, es decir: hex(int(int/int))
                potOctal = oct(int(int(v1) ** int(v2)))
                print("En base \033[1m", usr_bases_dictionary[usr_base],"es:", potOctal,"\033[0m")
                my_octal_number = int(eval(potOctal)) 
                print("\033[1mEl resultado en decimal es: ", my_octal_number,"\033[0m")  
                
    
################## FIN BASE OCTAL #################

#

################## INICIA BASE BINARIA #################


    if curren_base == 'Binaria':

        # Aquí El contador "i+1" ayuda a saber cual es el subindice de la OPERACIÓN actualmente a realizar.
# \033[1m...\033[0m        
        print("LA OPERACION \033[1m",(i+1),"\033[0m es:\033[1m",usr_OPE_dictionary[usr_base],
              "\033[0m; Y ESTÁ EN BASE \033[1mBINARIA\033[0m.")
        
        # Haz un cambio implicito del valor de 'lista_Operando1[i]'' a tipo Decimal con 'eval()''.
        v1 = eval(lista_Operando1[i])
       # Haz un cambio implicito del valor de 'lista_Operando2[i]'' a tipo Decimal con 'eval()''.
        v2 = eval(Lista_Operando2[i])
        print("\nSus operandos tienen el valor en base decimal de:")
        print ("v1=",v1,"\nv2=",v2)
        
        print("\nSus operandos tienen el valor en base Binaria de:")
        print ("v1=",bin(v1),"\nv2=",bin(v2),"\n")
        
        # PARA v1:
        #Declaro un swich tipo 'bool' para permitir o negar la operación si V1 no es del tipo correcto de acuerdo a la base
        blnv1AceptaOpBinaria = False 
        if type(v1)==type(vIntRef) or type(v1)==type(vFloatRef):
            print ("La variable v1 es de tipo:", type(v1), ", por lo que se acepta")
            blnv1AceptaOpBinaria = True
        
        # Establezco un valor limite maximo y minimo para V1 y uso el swich anterior 
        # para reafirmar o cancelar la ejecución de la operación    
        if v1<=2147483647 and v1>=-2147483647:
            print ("v1 también entra en los rangos permitidos, y también se acepta")
            blnv1AceptaOpBinaria = True
        else:
            print ("La variable v1 NO entra en los rangos permitidos, por lo que SE RECHAZA")
            blnv1AceptaOpBinaria = False
            
        # PARA v2:
        #Declaro un swich tipo 'bool' para permitir o negar la operación si V1 no es del tipo correcto de acuerdo a la base
        blnv2AceptaOpBinaria = False 
        if type(v2)==type(vIntRef) or type(v2)==type(vFloatRef):
            print ("La variable v2 es de tipo:", type(v1), ", por lo que se acepta")
            blnv2AceptaOpBinaria = True
            
        # Establezco un valor limite maximo y minimo para V1 y uso el swich anterior 
        # para reafirmar o cancelar la ejecución de la operación    
        if v1<=2147483647 and v1>=-2147483647:
            print ("v2 también entra en los rangos permitidos, y también se acepta")
            blnv2AceptaOpBinaria = True
        else:
            print ("\nLa variable v2 NO entra en los rangos permitidos, por lo que SE RECHAZA")
            blnv2AceptaOpBinaria = False
                
        ## Si lo swiches anteriores son verdaderos se ejecuta la operación
        ### si no, habra aparecido un mensaje donde se ubica el fallo.
        if blnv1AceptaOpBinaria== True and blnv2AceptaOpBinaria == True:
            print("\nPor lo tanto, los valores que has introducido \033[1mSON ACEPTADOS\033[0m para realizar dicha operación")
            #*# Inicia zona de ejecucion de operación:
            
            ## Imprimi para verlo, 
            ## esta linea se puede comentar para limpiar el código
            #print(usr_OPE_Lista[i]) 
            
            my_operation_symbol = usr_OPE_Lista[i]
                 
                
            if my_operation_symbol == '+':

                v1 = str(v1)
                v2 = str(v2)
                
                print("\n\033[1mA PARTIR DE ESTE MOMENTO LA OPERACIÓN SE HACE EXCLUSIVAMENTE DE LA BASE BINARIA:\033[0m")
                
                print("\nEl resultado de la operación:\033[1m", my_operators_dictionary[my_operation_symbol],
                      bin(int(v1)), usr_OPE_Lista[i], bin(int(v2)))
                
                # Hago conversión explicita, es decir: hex(int(int/int))
                sumabin = bin(int(int(v1) + int(v2)))
                print("En base \033[1m", usr_bases_dictionary[usr_base],"es:", sumabin,"\033[0m")
                my_binary_number = int(eval(sumabin)) 
                print("\033[1mEl resultado en decimal es: ", my_binary_number,"\033[0m") 
                  
            
            if my_operation_symbol == '-':

                v1 = str(v1)
                v2 = str(v2)
                
                print("\n\033[1mA PARTIR DE ESTE MOMENTO LA OPERACIÓN SE HACE EXCLUSIVAMENTE DE LA BASE BINARIA:\033[0m")
                
                print("\nEl resultado de la operación:\033[1m", my_operators_dictionary[my_operation_symbol],
                      bin(int(v1)), usr_OPE_Lista[i], bin(int(v2)))
                
                # Hago conversión explicita, es decir: hex(int(int/int))
                restabin = bin(int(int(v1) - int(v2)))
                print("En base \033[1m", usr_bases_dictionary[usr_base],"es:", restabin,"\033[0m")
                my_binary_number = int(eval(restabin)) 
                print("\033[1mEl resultado en decimal es: ", my_binary_number,"\033[0m") 
                
            
            if my_operation_symbol == '*':

                v1 = str(v1)
                v2 = str(v2)
                
                print("\n\033[1mA PARTIR DE ESTE MOMENTO LA OPERACIÓN SE HACE EXCLUSIVAMENTE DE LA BASE BINARIA:\033[0m")
                
                print("\nEl resultado de la operación:\033[1m", my_operators_dictionary[my_operation_symbol],
                      bin(int(v1)), usr_OPE_Lista[i], bin(int(v2)))
                
                # Hago conversión explicita, es decir: hex(int(int/int))
                multiBin = bin(int(int(v1) * int(v2)))
                print("En base \033[1m", usr_bases_dictionary[usr_base],"es:", multiBin,"\033[0m")
                my_binary_number = int(eval(multiBin)) 
                print("\033[1mEl resultado en decimal es: ", my_binary_number,"\033[0m") 

                
            if my_operation_symbol == '/':
                               
                v1 = str(v1)
                v2 = str(v2)
                
                print("\n\033[1mA PARTIR DE ESTE MOMENTO LA OPERACIÓN SE HACE EXCLUSIVAMENTE DE LA BASE BINARIA:\033[0m")
                
                print("\nEl resultado de la operación:\033[1m", my_operators_dictionary[my_operation_symbol],
                      bin(int(v1)), usr_OPE_Lista[i], bin(int(v2)))
                
                # Hago conversión explicita, es decir: hex(int(int/int))
                divbin = bin(int(int(v1) / int(v2)))
                print("En base \033[1m", usr_bases_dictionary[usr_base],"es:", divbin,"\033[0m")
                my_binary_number = int(eval(divbin)) 
                print("\033[1mEl resultado en decimal es: ", my_binary_number,"\033[0m") 
                
                

            if my_operation_symbol == '**':
 
                v1 = str(v1)
                v2 = str(v2)
                
                print("\n\033[1mA PARTIR DE ESTE MOMENTO LA OPERACIÓN SE HACE EXCLUSIVAMENTE DE LA BASE BINARIA:\033[0m")
                
                print("\nEl resultado de la operación:\033[1m", my_operators_dictionary[my_operation_symbol],
                      bin(int(v1)), usr_OPE_Lista[i], bin(int(v2)))
                
                # Hago conversión explicita, es decir: hex(int(int/int))
                potHex = bin(int(int(v1) ** int(v2)))
                print("En base \033[1m", usr_bases_dictionary[usr_base],"es:", potHex,"\033[0m")
                my_binary_number = int(eval(potHex)) 
                print("\033[1mEl resultado en decimal es: ", my_binary_number,"\033[0m")  
                

################## FIN BASE BINARIA #################

#

################## INICIA BASE HEXADECIMAL ##############

    if curren_base == 'Hexadecimal':

        # Aquí El contador "i+1" ayuda a saber cual es el subindice de la OPERACIÓN actualmente a realizar.
# \033[1m...\033[0m        
        print("LA OPERACIÓN \033[1m",(i+1),"\033[0m es:\033[1m",usr_OPE_dictionary[usr_base],
              "\033[0m; Y ESTÁ EN BASE \033[1mHEXADECIMAL\033[0m.")
        
        # Haz un cambio implicito del valor de 'lista_Operando1[i]'' a tipo Decimal con 'eval()''.
        v1 = eval(lista_Operando1[i])
       # Haz un cambio implicito del valor de 'lista_Operando2[i]'' a tipo Decimal con 'eval()''.
        v2 = eval(Lista_Operando2[i])
        print("\nSus operandos tienen el valor en base Decimal de:")
        print ("v1=",v1,"\nv2=",v2)
        
        print("\nSus operandos tienen el valor en base Hexadecimal de:")
        print ("v1=",hex(v1),"\nv2=",hex(v2),"\n")
        
        # PARA v1:
        #Declaro un swich tipo 'bool' para permitir o negar la operación si V1 no es del tipo correcto de acuerdo a la base
        blnv1AceptaOpHexadecimal = False 
        
        print("\nAqui verificamos los valores de ambos operandos en terminos de tipo ENTERO:\n")
        
        if type(v1)==type(vIntRef) or type(v1)==type(vFloatRef):
            print ("La variable v1 es de tipo:", type(v1), ", por lo que se acepta")
            blnv1AceptaOpHexadecimal = True
        
        # Establezco un valor limite maximo y minimo para V1 y uso el swich anterior 
        # para reafirmar o cancelar la ejecución de la operación    
        if v1<=2147483647 and v1>=-2147483647:
            print ("v1 también entra en los rangos permitidos, y también se acepta")
            blnv1AceptaOpHexadecimal = True
        else:
            print ("La variable v1 NO entra en los rangos permitidos, por lo que SE RECHAZA")
            blnv1AceptaOpHexadecimal = False
            
        # PARA v2:
        #Declaro un swich tipo 'bool' para permitir o negar la operación si V1 no es del tipo correcto de acuerdo a la base
        blnv2AceptaOpHexadecimal = False 
        if type(v2)==type(vIntRef) or type(v2)==type(vFloatRef):
            print ("La variable v2 es de tipo:", type(v1), ", por lo que se acepta")
            blnv2AceptaOpHexadecimal = True
            
        # Establezco un valor limite maximo y minimo para V1 y uso el swich anterior 
        # para reafirmar o cancelar la ejecución de la operación    
        if v1<=2147483647 and v1>=-2147483647:
            print ("v2 también entra en los rangos permitidos, y también se acepta")
            blnv2AceptaOpHexadecimal = True
        else:
            print ("\nLa variable v2 NO entra en los rangos permitidos, por lo que SE RECHAZA")
            blnv2AceptaOpHexadecimal = False
                
        ## Si lo swiches anteriores son verdaderos se ejecuta la operación
        ### si no, habra aparecido un mensaje donde se ubica el fallo.
        if blnv1AceptaOpHexadecimal== True and blnv2AceptaOpHexadecimal == True:
            print("\nPor lo tanto, los valores que has introducido \033[1mSON ACEPTADOS\033[0m para realizar dicha operación")
            #*# Inicia zona de ejecucion de operación:
            
            ## Imprimi para verlo, 
            ## esta linea se puede comentar para limpiar el código
            #print(usr_OPE_Lista[i]) 
            
            my_operation_symbol = usr_OPE_Lista[i]
                
            if my_operation_symbol == '+':

                v1 = str(v1)
                v2 = str(v2)
                
                print("\n\033[1mA PARTIR DE ESTE MOMENTO LA OPERACIÓN SE HACE EXCLUSIVAMENTE DE LA BASE HEXADECIMAL:\033[0m")
                
                print("\nEl resultado de la operación:\033[1m", my_operators_dictionary[my_operation_symbol],
                      hex(int(v1)), usr_OPE_Lista[i], hex(int(v2)))
                
                # Hago conversión explicita, es decir: hex(int(int/int))
                sumaHex = hex(int(int(v1) + int(v2)))
                print("En base \033[1m", usr_bases_dictionary[usr_base],"es:", sumaHex,"\033[0m")
                my_hexadecimal_number = int(eval(sumaHex)) 
                print("\033[1mEl resultado en decimal es: ", my_hexadecimal_number,"\033[0m") 
                  
            
            if my_operation_symbol == '-':
                
                v1 = str(v1)
                v2 = str(v2)
                
                print("\n\033[1mA PARTIR DE ESTE MOMENTO LA OPERACIÓN SE HACE EXCLUSIVAMENTE DE LA BASE HEXADECIMAL:\033[0m")
                
                print("\nEl resultado de la operación:\033[1m", my_operators_dictionary[my_operation_symbol],
                      hex(int(v1)), usr_OPE_Lista[i], hex(int(v2)))
                
                # Hago conversión explicita, es decir: hex(int(int/int))
                restaHex = hex(int(int(v1) - int(v2)))
                print("En base \033[1m", usr_bases_dictionary[usr_base],"es:", restaHex,"\033[0m")
                my_hexadecimal_number = int(eval(restaHex)) 
                print("\033[1mEl resultado en decimal es: ", my_hexadecimal_number,"\033[0m") 
                
            
            if my_operation_symbol == '*':

                v1 = str(v1)
                v2 = str(v2)
                
                print("\n\033[1mA PARTIR DE ESTE MOMENTO LA OPERACIÓN SE HACE EXCLUSIVAMENTE DE LA BASE HEXADECIMAL:\033[0m")
                
                print("\nEl resultado de la operación:\033[1m", my_operators_dictionary[my_operation_symbol],
                      hex(int(v1)), usr_OPE_Lista[i], hex(int(v2)))
                
                # Hago conversión explicita, es decir: hex(int(int/int))
                multiHex = hex(int(int(v1) * int(v2)))
                print("En base \033[1m", usr_bases_dictionary[usr_base],"es:", multiHex,"\033[0m")
                my_hexadecimal_number = int(eval(multiHex)) 
                print("\033[1mEl resultado en decimal es: ", my_hexadecimal_number,"\033[0m") 
                
            if my_operation_symbol == '/':

                v1 = str(v1)
                v2 = str(v2)
                
                print("\n\033[1mA PARTIR DE ESTE MOMENTO LA OPERACIÓN SE HACE EXCLUSIVAMENTE DE LA BASE HEXADECIMAL:\033[0m")
                
                print("\nEl resultado de la operación:\033[1m", my_operators_dictionary[my_operation_symbol],
                      hex(int(v1)), usr_OPE_Lista[i], hex(int(v2)))
                
                # Hago conversión explicita, es decir: hex(int(int/int))
                divHex = hex(int(int(v1) / int(v2)))
                print("En base \033[1m", usr_bases_dictionary[usr_base],"es:", divHex,"\033[0m")
                my_hexadecimal_number = int(eval(divHex)) 
                print("\033[1mEl resultado en decimal es: ", my_hexadecimal_number,"\033[0m")  
                

            if my_operation_symbol == '**':

                v1 = str(v1)
                v2 = str(v2)
                
                print("\n\033[1mA PARTIR DE ESTE MOMENTO LA OPERACIÓN SE HACE EXCLUSIVAMENTE DE LA BASE HEXADECIMAL:\033[0m")
                
                print("\nEl resultado de la operación:\033[1m", my_operators_dictionary[my_operation_symbol],
                      hex(int(v1)), usr_OPE_Lista[i], hex(int(v2)))
                
                # Hago conversión explicita, es decir: hex(int(int/int))
                potHex = hex(int(int(v1) ** int(v2)))
                print("En base \033[1m", usr_bases_dictionary[usr_base],"es:", potHex,"\033[0m")
                my_hexadecimal_number = int(eval(potHex)) 
                print("\033[1mEl resultado en decimal es: ", my_hexadecimal_number,"\033[0m")  
                
                

################## FIN BASE HEXADECIMAL #################

print("\n_________________-------------_______________________")
print("_________________-------------_______________________\n")
print("  FIN DEL PROGRAMA, LA CALCULADORA HA TERMINADO        ")
print("\n_________________-------------_______________________")
print("_________________-------------_______________________\n")
# Out:
# _________________-------------_______________________
# _________________-------------_______________________
#
#
#  - Diccionario de Bases:
# La Bases que puede usar esta calculadora son: {'H': 'Hexadecimal', 'D': 'Decimal', 'O': 'Octal', 'B': 'Binaria'}
# La variable: 'my_bases_dictionary' es de tipo:  <class 'dict'>
#
#  - Diccionario de Operadores:
# Los Operadores que se pueden usar son: {'+': 'Suma', '-': 'Resta', '*': 'Multiplicación', '/': 'División', '**': 'Potencia'}
# La variable: 'my_operators_dictionary' es de tipo:  <class 'dict'>
#
# _________________-------------_______________________
# _________________-------------_______________________
#
# Separadas por un espacio.
# SOLO escribe la LETRA inicial -EN MAYUSCULA-
# De 5 (CINCO) bases para TUS operaciones: por ejemplo:
# B O H D BB O H D B
# Elegiste que la base de tu 1er operación sea:  Binaria
# Elegiste que la base de tu 2da operación sea:  Octal
# Elegiste que la base de tu 3ra operación sea:  Hexadecimal
# ...
